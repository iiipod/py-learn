# %%
# coding:gb2312
import requests
from bs4 import BeautifulSoup
import psycopg2
import os

head = {'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.19 Safari/537.36'}
html = 'http://top.baidu.com/boards?fr=topindex'

res = requests.get(html, headers=head)

soup = BeautifulSoup(res.text, from_encoding="gb2312")
for i in range(len(soup.findAll('div', attrs={"class": "all-list"}))):
    print soup.findAll('div', attrs={"class": "all-list"})[0].text
# Out:
#  ÈÈËÑ
#
#
#
# ÈÈÃÅËÑË÷
# ÊÀËµÐÂ´Ê
#
#
#
#
#
#
#
#  ÈÈËÑ
#
#
#
# ÈÈÃÅËÑË÷
# ÊÀËµÐÂ´Ê
#
#
#
#
#
#
#
#  ÈÈËÑ
#
#
#
# ÈÈÃÅËÑË÷
# ÊÀËµÐÂ´Ê
#
#
#
#
#
#
#
#  ÈÈËÑ
#
#
#
# ÈÈÃÅËÑË÷
# ÊÀËµÐÂ´Ê
#
#
#
#
#
#
#
#  ÈÈËÑ
#
#
#
# ÈÈÃÅËÑË÷
# ÊÀËµÐÂ´Ê
#
#
#
#
#
#
#
#  ÈÈËÑ
#
#
#
# ÈÈÃÅËÑË÷
# ÊÀËµÐÂ´Ê
#
#
#
#
#
#
#
#  ÈÈËÑ
#
#
#
# ÈÈÃÅËÑË÷
# ÊÀËµÐÂ´Ê
#
#
#
#
#
#
#
#  ÈÈËÑ
#
#
#
# ÈÈÃÅËÑË÷
# ÊÀËµÐÂ´Ê
#
#
#
#
#
#
#
#  ÈÈËÑ
#
#
#
# ÈÈÃÅËÑË÷
# ÊÀËµÐÂ´Ê
#
#
#
#
#
#
#
#  ÈÈËÑ
#
#
#
# ÈÈÃÅËÑË÷
# ÊÀËµÐÂ´Ê
#
#
#
#
#
#
#
#  ÈÈËÑ
#
#
#
# ÈÈÃÅËÑË÷
# ÊÀËµÐÂ´Ê
#
#
#
#
#
#
#
#  ÈÈËÑ
#
#
#
# ÈÈÃÅËÑË÷
# ÊÀËµÐÂ´Ê
#
#
#
#
#
#
#
#  ÈÈËÑ
#
#
#
# ÈÈÃÅËÑË÷
# ÊÀËµÐÂ´Ê
